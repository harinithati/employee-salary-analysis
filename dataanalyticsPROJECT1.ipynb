# %%
import pandas as pd

data = {
    "EmployeeID": [1,2,3,4,5,6],
    "Name": ["Ramesh","Sita","Arjun","Meena","Ravi","Priya"],
    "Department": ["HR","IT","Finance","IT","HR","Finance"],
    "Salary": [40000,70000,65000,80000,42000,60000],
    "Experience": [2,5,4,6,3,3]
}

df = pd.DataFrame(data)

df
# Out:
#    EmployeeID    Name Department  Salary  Experience
# 0           1  Ramesh         HR   40000           2
# 1           2    Sita         IT   70000           5
# 2           3   Arjun    Finance   65000           4
# 3           4   Meena         IT   80000           6
# 4           5    Ravi         HR   42000           3
# 5           6   Priya    Finance   60000           3

# %%
df.to_csv("employee_salary.csv", index=False)

# %%
from google.colab import files
files.download("employee_salary.csv")

# %%
import pandas as pd

df = pd.read_csv("employee_salary.csv")
df.head()
# Out:
#    EmployeeID    Name Department  Salary  Experience
# 0           1  Ramesh         HR   40000           2
# 1           2    Sita         IT   70000           5
# 2           3   Arjun    Finance   65000           4
# 3           4   Meena         IT   80000           6
# 4           5    Ravi         HR   42000           3

# %%
df.shape
# Out:
# (6, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeID  6 non-null      int64
#  1   Name        6 non-null      object
#  2   Department  6 non-null      object
#  3   Salary      6 non-null      int64
#  4   Experience  6 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 372.0+ bytes

# %%
df.describe()
# Out:
#        EmployeeID        Salary  Experience
# count    6.000000      6.000000    6.000000
# mean     3.500000  59500.000000    3.833333
# std      1.870829  15795.568999    1.471960
# min      1.000000  40000.000000    2.000000
# 25%      2.250000  46500.000000    3.000000
# 50%      3.500000  62500.000000    3.500000
# 75%      4.750000  68750.000000    4.750000
# max      6.000000  80000.000000    6.000000

# %%
df['Salary'].max()
# Out:
# 80000

# %%
df[df['Salary'] == df['Salary'].max()]
# Out:
#    EmployeeID   Name Department  Salary  Experience
# 3           4  Meena         IT   80000           6

# %%
df['Salary'].min()
# Out:
# 40000

# %%
df[df['Salary'] == df['Salary'].min()]
# Out:
#    EmployeeID    Name Department  Salary  Experience
# 0           1  Ramesh         HR   40000           2

# %%
df.groupby('Department')['Salary'].mean()
# Out:
# Department
# Finance    62500.0
# HR         41000.0
# IT         75000.0
# Name: Salary, dtype: float64

# %%
df.groupby('Experience')['Salary'].mean()
# Out:
# Experience
# 2    40000.0
# 3    51000.0
# 4    65000.0
# 5    70000.0
# 6    80000.0
# Name: Salary, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Salary'])
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Number of Employees")
plt.show()

# %%
dept_salary = df.groupby('Department')['Salary'].mean()

dept_salary.plot(kind='bar')
plt.title("Average Salary by Department")
plt.xlabel("Department")
plt.ylabel("Average Salary")
plt.show()

# %%
plt.scatter(df['Experience'], df['Salary'])
plt.title("Experience vs Salary")
plt.xlabel("Experience (Years)")
plt.ylabel("Salary")
plt.show()

# %%
df[['Experience', 'Salary']].corr()
# Out:
#             Experience    Salary
# Experience    1.000000  0.924713
# Salary        0.924713  1.000000

# %%
df.sort_values(by='Salary', ascending=False).head(3)
# Out:
#    EmployeeID   Name Department  Salary  Experience
# 3           4  Meena         IT   80000           6
# 1           2   Sita         IT   70000           5
# 2           3  Arjun    Finance   65000           4

# %%
df['Salary'].max() - df['Salary'].min()
# Out:
# 40000
